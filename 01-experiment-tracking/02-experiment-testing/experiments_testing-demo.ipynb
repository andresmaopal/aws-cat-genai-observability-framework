# %% [markdown]
# # 01 - Experiments tracking - AWS Strands Agents
#
# This notebook demonstrates the unified testing approach using the `run_test()` method with human-readable results.

# %% [markdown]
# ## Setup
# ______________________________________________________________

# %%
# %pip install ipywidgets  "strands-agents" "strands-agents-tools" -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import time
import uuid
import boto3
import yaml
from datetime import datetime
from utils import UnifiedTester

# %%
# Initialize Unified Tester
tester = UnifiedTester()

# Load configuration
with open('config_experiments.yml', 'r') as f:
    config = yaml.safe_load(f)

prompts = config['system_prompts']
test_queries = config['test_queries']

print("✅ Unified Tester initialized!")
print(f"✅ Available Prompts: {list(prompts.keys())}")
print(f"✅ Number of Test queries: {len(test_queries)}")
# Out:
# ✅ Unified Tester initialized!
# ✅ Available Prompts: ['version1', 'version2']
# ✅ Number of Test queries: 2

# %% [markdown]
# ## Tools Definition
# __________________________________________________________________________________

# %% [markdown]
# ### Dependencies setup

# %%
from strands_tools import retrieve, current_time
from strands import Agent, tool
from strands.models.bedrock import BedrockModel
import os

# %%
kb_name = "restaurant-assistant"
dynamodb = boto3.resource("dynamodb")
smm_client = boto3.client("ssm")
table_name = smm_client.get_parameter(
    Name=f"{kb_name}-table-name", WithDecryption=False
)
table = dynamodb.Table(table_name["Parameter"]["Value"])
kb_id = smm_client.get_parameter(Name=f"{kb_name}-kb-id", WithDecryption=False)
print("DynamoDB table:", table_name["Parameter"]["Value"])
print("Knowledge Base Id:", kb_id["Parameter"]["Value"])

#Knowledge Base
os.environ["KNOWLEDGE_BASE_ID"] = kb_id["Parameter"]["Value"]
# Out:
# DynamoDB table: restaurant-bookings
# Knowledge Base Id: XGIDQ0ALGL

# %% [markdown]
# #### Tools setup

# %%
# %%writefile tool_get_booking_details.py

from strands import tool
import boto3 

@tool
def tool_booking_details(booking_id: str, restaurant_name: str) -> dict:
    """Get the relevant details for booking_id in restaurant_name
    Args:
        booking_id: the id of the reservation
        restaurant_name: name of the restaurant handling the reservation

    Returns:
        booking_details: the details of the booking in JSON format
    """

    try:
        response = table.get_item(
            Key={"booking_id": booking_id, "restaurant_name": restaurant_name}
        )
        if "Item" in response:
            return response["Item"]
        else:
            return f"No booking found with ID {booking_id}"
    except Exception as e:
        return str(e)
# Out:
# Overwriting tool_get_booking_details.py

# %%
# %%writefile tool_delete_booking.py

from strands import tool
import boto3 

@tool
def tool_delete_booking(booking_id: str, restaurant_name:str) -> str:
    """delete an existing booking_id at restaurant_name
    Args:
        booking_id: the id of the reservation
        restaurant_name: name of the restaurant handling the reservation

    Returns:
        confirmation_message: confirmation message
    """
    kb_name = 'restaurant-assistant'
    dynamodb = boto3.resource('dynamodb')
    smm_client = boto3.client('ssm')
    table_name = smm_client.get_parameter(
        Name=f'{kb_name}-table-name',
        WithDecryption=False
    )
    table = dynamodb.Table(table_name["Parameter"]["Value"])
    try:
        response = table.delete_item(Key={'booking_id': booking_id, 'restaurant_name': restaurant_name})
        if response['ResponseMetadata']['HTTPStatusCode'] == 200:
            return f'Booking with ID {booking_id} deleted successfully'
        else:
            return f'Failed to delete booking with ID {booking_id}'
    except Exception as e:
        return str(e)
# Out:
# Overwriting tool_delete_booking.py

# %%
# %%writefile tool_create_booking.py

#Alternativelly, you can use the TOOL_SPEC approach when defining your tool

from typing import Any
from strands.types.tools import ToolResult, ToolUse
import boto3
import uuid


TOOL_SPEC = {
    "name": "tool_create_booking",
    "description": "Create a new booking at restaurant_name",
    "inputSchema": {
        "json": {
            "type": "object",
            "properties": {
                "date": {
                    "type": "string",
                    "description": """The date of the booking in the format YYYY-MM-DD. 
                    Do NOT accept relative dates like today or tomorrow. 
                    Ask for today's date for relative date."""
                },
                "hour": {
                    "type": "string",
                    "description": "the hour of the booking in the format HH:MM"
                },
                "restaurant_name": {
                    "type": "string",
                    "description": "name of the restaurant handling the reservation"
                },
                "guest_name": {
                    "type": "string",
                    "description": "The name of the customer to have in the reservation"
                },
                "num_guests": {
                    "type": "integer",
                    "description": "The number of guests for the booking"
                }
            },
            "required": ["date", "hour", "restaurant_name", "guest_name", "num_guests"]
        }
    }
}
# Function name must match tool name
def tool_create_booking(tool: ToolUse, **kwargs: Any) -> ToolResult:
    kb_name = 'restaurant-assistant'
    dynamodb = boto3.resource('dynamodb')
    smm_client = boto3.client('ssm')
    table_name = smm_client.get_parameter(
        Name=f'{kb_name}-table-name',
        WithDecryption=False
    )
    table = dynamodb.Table(table_name["Parameter"]["Value"])
    
    tool_use_id = tool["toolUseId"]
    date = tool["input"]["date"]
    hour = tool["input"]["hour"]
    restaurant_name = tool["input"]["restaurant_name"]
    guest_name = tool["input"]["guest_name"]
    num_guests = tool["input"]["num_guests"]
    
    results = f"Creating reservation for {num_guests} people at {restaurant_name}, " \
              f"{date} at {hour} in the name of {guest_name}"
    print(results)
    try:
        booking_id = str(uuid.uuid4())[:8]
        table.put_item(
            Item={
                'booking_id': booking_id,
                'restaurant_name': restaurant_name,
                'date': date,
                'name': guest_name,
                'hour': hour,
                'num_guests': num_guests
            }
        )
        return {
            "toolUseId": tool_use_id,
            "status": "success",
            "content": [{"text": f"Reservation created with booking id: {booking_id}"}]
        } 
    except Exception as e:
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": str(e)}]
        }
# Out:
# Overwriting tool_create_booking.py

# %%
import tool_create_booking
import tool_delete_booking
import tool_get_booking_details

# %% [markdown]
# #### Tool List

# %%
#Tools list
tool_list = [retrieve, current_time, tool_get_booking_details, tool_create_booking, tool_delete_booking]

# %% [markdown]
# ## Tests Setup
# _______________________________________________________________________________________________

# %%
# Test 1: Multiple models, single system prompt, single query

# Note: CSV results are automatically saved to test_results/ folder (save_to_csv=True by default)
results1 = tester.run_test(
    models=[
        "bedrock/openai.gpt-oss-120b-1:0",
        "bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0"
    ],  # LiteLLM endpoints
    system_prompts=["version2"],  # System prompts to test from config_experiments.yml
    queries=test_queries,  # Test all queries from config_experiments.yml
    prompts_dict=prompts,  # Dictionary of prompts
    tool=tool_list,  # Tools to test
    save_to_csv=True, # Default True
    conversation_window=5 # Last N conversation interactions to store as context. Default of 5.
)

tester.display_results(results1)
# Out:
# 🚀 Starting LiteLLM Test Suite
# 📊 Total combinations to test: 4
# 🤖 Models: ['bedrock/openai.gpt-oss-120b-1:0', 'bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0']
# 📝 Prompts: ['version2']
# ❓ Queries: 2 query(ies)
# ================================================================================
#
# [1/4] Testing: bedrock/openai.gpt-oss-120b-1:0 | version2
# Query: Make a reservation for tonight at 'The Smoking Ember' for 5 persons At 8pm in the name of Andres
# ------------------------------------------------------------
# 🔧 Using AWS region: us-east-1
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# ⚠️ Streaming issue detected, trying direct LiteLLM call with stream=False
# ✅ Direct LiteLLM call successful
# <answer>Restaurant Helper
#
# Good evening. I will proceed with your reservation request. Please allow me a moment to confirm that “The Smoking Ember” is listed in our directory.</answer>
# ✅ SUCCESS | Time: 2.78s
#
# [2/4] Testing: bedrock/openai.gpt-oss-120b-1:0 | version2
# Query: Cancel the reservation for Andres tonight at 'The Smoking Ember'for 5 persons At 8pm
# ------------------------------------------------------------
# 🔧 Using AWS region: us-east-1
# <answer>Restaurant Helper: To proceed with cancelling the reservation at The Smoking Ember, could you please provide the reservation (booking) ID?</answer><answer>Restaurant Helper: To proceed with cancelling the reservation at The Smoking Ember, could you please provide the reservation (booking) ID?</answer>
#
# ✅ SUCCESS | Time: 1.40s
#
# [3/4] Testing: bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0 | version2
# Query: Make a reservation for tonight at 'The Smoking Ember' for 5 persons At 8pm in the name of Andres
# ------------------------------------------------------------
# 🔧 Using AWS region: us-east-1
# Restaurant Helper: Good day! I'd be happy to help you make a reservation at The Smoking Ember.
#
# Let me first check if The Smoking Ember is in our restaurant directory, and then I'll assist with creating your reservation for tonight.
# Tool #1: retrieve
# Now, I need to get today's date to create your reservation for tonight.
# Tool #2: current_time
# Now I'll create your reservation:
# Tool #3: tool_create_booking
# Creating reservation for 5 people at The Smoking Ember, 2025-11-13 at 20:00 in the name of Andres
# <answer>Restaurant Helper: I apologize, but I'm currently unable to create your reservation at The Smoking Ember. It seems there might be a technical issue with our booking system.
#
# For immediate assistance with your reservation for tonight at The Smoking Ember for 5 people at 8:00 PM under the name Andres, please call our reservation line at +1 999 999 99 9999.
#
# Thank you for your understanding.</answer><answer>Restaurant Helper: I apologize, but I'm currently unable to create your reservation at The Smoking Ember. It seems there might be a technical issue with our booking system.
#
# For immediate assistance with your reservation for tonight at The Smoking Ember for 5 people at 8:00 PM under the name Andres, please call our reservation line at +1 999 999 99 9999.
#
# Thank you for your understanding.</answer>
#
# ✅ SUCCESS | Time: 12.14s
#
# [4/4] Testing: bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0 | version2
# Query: Cancel the reservation for Andres tonight at 'The Smoking Ember'for 5 persons At 8pm
# ------------------------------------------------------------
# 🔧 Using AWS region: us-east-1
# Restaurant Helper here. I'll help you cancel the reservation at The Smoking Ember, but I'll need the booking ID to proceed with the cancellation.
#
# To cancel a reservation, I need the specific booking ID associated with your reservation. This would have been provided when the reservation was initially made.
#
# Could you please provide the booking ID for Andres' reservation at The Smoking Ember? Once I have that information, I can proceed with the cancellation.Restaurant Helper here. I'll help you cancel the reservation at The Smoking Ember, but I'll need the booking ID to proceed with the cancellation.
#
# To cancel a reservation, I need the specific booking ID associated with your reservation. This would have been provided when the reservation was initially made.
#
# Could you please provide the booking ID for Andres' reservation at The Smoking Ember? Once I have that information, I can proceed with the cancellation.
#
# ✅ SUCCESS | Time: 2.52s
#
# 🎉 Test Suite Completed! 4 results generated.
# 📁 Results automatically saved to test_results/test_results_20251113_173221.csv
#
# 📈 RESULTS SUMMARY
# ==================================================
# Total Tests: 4
# ✅ Successful: 4 (100.0%)
# ❌ Failed: 0 (0.0%)
# ⏱️  Response Times - Avg: 4.71s | Min: 1.40s | Max: 12.14s
#
# 🤖 MODEL PERFORMANCE
# ==================================================
# bedrock/openai.gpt-oss-120b-1:0                    | Success: 100.0% | Avg Time:   2.09s | Tests: 2
# bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0 | Success: 100.0% | Avg Time:   7.33s | Tests: 2
#
# 📝 PROMPT PERFORMANCE
# ==================================================
# version2             | Success: 100.0% | Avg Time:   4.71s | Tests: 4

# %%
# Test 2: Single model, multiple prompts, single custom query

results2 = tester.run_test(
    models=["bedrock/us.anthropic.claude-opus-4-1-20250805-v1:0"],  # Single LiteLLM endpoint
    system_prompts=["version1", "version2"],  # Multiple prompts
    queries="Bring me the menu for Rice & Spice and do a reservation there for Diana for 5 persons At 8pm",  # Custom query
    prompts_dict=prompts,
    tool=tool_list,
    conversation_window=5
)

tester.display_results(results2)
# Out:
# 🚀 Starting LiteLLM Test Suite
# 📊 Total combinations to test: 2
# 🤖 Models: ['bedrock/us.anthropic.claude-opus-4-1-20250805-v1:0']
# 📝 Prompts: ['version1', 'version2']
# ❓ Queries: 1 query(ies)
# ================================================================================
#
# [1/2] Testing: bedrock/us.anthropic.claude-opus-4-1-20250805-v1:0 | version1
# Query: Bring me the menu for Rice & Spice and do a reservation there for Diana for 5 persons At 8pm
# ------------------------------------------------------------
# 🔧 Using AWS region: us-east-1
# I'll help you get the menu for Rice & Spice and make a reservation for Diana. Let me retrieve that information and create the booking for you.
# Tool #1: retrieve
# Now I need to create the reservation. However, I need to know the specific date for your reservation. Could you please provide the date you'd like to book for?
#
# In the meantime, let me get today's date to help with the booking:
# Tool #2: current_time
# To complete your reservation at Rice & Spice for Diana (5 people at 8pm), I need to know which date you'd like. Would you like to make the reservation for today (November 13, 2025) or another date?
#
# Here's the **Rice & Spice** menu for you:
#
# **Pan-Asian Fusion Cuisine**
#
# **SMALL BITES**
# - Pork Belly Bao Buns with hoisin and pickled daikon - $12
# - Korean Fried Chicken with gochujang glaze - $14
# - Green Papaya Salad with peanuts and chili lime dressing - $10
#
# **MAIN DISHES**
# - Miso Black Cod with ginger scallion oil - $28
# - Red Curry with coconut milk, seasonal vegetables, and jasmine rice - $19
# - Bibimbap with bulgogi beef and sunny-side-up egg - $17
# - Singapore Chili Crab Noodles - $24
#
# **SWEETS**
# - Mango Sticky Rice - $8
# - Matcha Tiramisu - $9
# - Black Sesame Ice Cream - $7
#
# Rice & Spice is located at 539 Fusion Boulevard, San Francisco, CA 94110.
#
# <answer>
# Restaurant Helper here! I've retrieved the Rice & Spice menu for you - they offer delicious Pan-Asian fusion cuisine with options ranging from small bites like Pork Belly Bao Buns to main dishes like Miso Black Cod and Singapore Chili Crab Noodles.
#
# To complete your reservation for Diana (party of 5 at 8pm), please let me know which date you'd like to book. Would you like it for today, November 13, 2025, or another date?
# </answer>To complete your reservation at Rice & Spice for Diana (5 people at 8pm), I need to know which date you'd like. Would you like to make the reservation for today (November 13, 2025) or another date?
#
# Here's the **Rice & Spice** menu for you:
#
# **Pan-Asian Fusion Cuisine**
#
# **SMALL BITES**
# - Pork Belly Bao Buns with hoisin and pickled daikon - $12
# - Korean Fried Chicken with gochujang glaze - $14
# - Green Papaya Salad with peanuts and chili lime dressing - $10
#
# **MAIN DISHES**
# - Miso Black Cod with ginger scallion oil - $28
# - Red Curry with coconut milk, seasonal vegetables, and jasmine rice - $19
# - Bibimbap with bulgogi beef and sunny-side-up egg - $17
# - Singapore Chili Crab Noodles - $24
#
# **SWEETS**
# - Mango Sticky Rice - $8
# - Matcha Tiramisu - $9
# - Black Sesame Ice Cream - $7
#
# Rice & Spice is located at 539 Fusion Boulevard, San Francisco, CA 94110.
#
# <answer>
# Restaurant Helper here! I've retrieved the Rice & Spice menu for you - they offer delicious Pan-Asian fusion cuisine with options ranging from small bites like Pork Belly Bao Buns to main dishes like Miso Black Cod and Singapore Chili Crab Noodles.
#
# To complete your reservation for Diana (party of 5 at 8pm), please let me know which date you'd like to book. Would you like it for today, November 13, 2025, or another date?
# </answer>
#
# ✅ SUCCESS | Time: 38.24s
#
# [2/2] Testing: bedrock/us.anthropic.claude-opus-4-1-20250805-v1:0 | version2
# Query: Bring me the menu for Rice & Spice and do a reservation there for Diana for 5 persons At 8pm
# ------------------------------------------------------------
# 🔧 Using AWS region: us-east-1
# I'll help you get the menu for Rice & Spice and create a reservation for Diana. Let me retrieve the menu and make the booking for you.
# Tool #1: retrieve
#
# Tool #2: current_time
# I need the specific date for your reservation. Since you want to book for 8pm, could you please provide the date you'd like to reserve (in YYYY-MM-DD format)? For example, would you like it for today (2025-11-13), tomorrow (2025-11-14), or another specific date?
#
# In the meantime, here's the menu for Rice & Spice:
#
# **Rice & Spice - Pan-Asian Fusion**
#
# **SMALL BITES**
# • Pork Belly Bao Buns with hoisin and pickled daikon - $12
# • Korean Fried Chicken with gochujang glaze - $14
# • Green Papaya Salad with peanuts and chili lime dressing - $10
#
# **MAIN DISHES**
# • Miso Black Cod with ginger scallion oil - $28
# • Red Curry with coconut milk, seasonal vegetables, and jasmine rice - $19
# • Bibimbap with bulgogi beef and sunny-side-up egg - $17
# • Singapore Chili Crab Noodles - $24
#
# **SWEETS**
# • Mango Sticky Rice - $8
# • Matcha Tiramisu - $9
# • Black Sesame Ice Cream - $7
#
# Rice & Spice is located at 539 Fusion Boulevard, San Francisco, CA 94110.
#
# <answer>
# Restaurant Helper
#
# I've retrieved the menu for Rice & Spice. To complete your reservation for Diana for 5 persons at 8pm, I need the specific date. Please provide the date in YYYY-MM-DD format (for example, 2025-11-13 for today or 2025-11-14 for tomorrow).
#
# **Rice & Spice Menu - Pan-Asian Fusion**
#
# **Small Bites**
# • Pork Belly Bao Buns - $12
# • Korean Fried Chicken - $14
# • Green Papaya Salad - $10
#
# **Main Dishes**
# • Miso Black Cod - $28
# • Red Curry - $19
# • Bibimbap - $17
# • Singapore Chili Crab Noodles - $24
#
# **Desserts**
# • Mango Sticky Rice - $8
# • Matcha Tiramisu - $9
# • Black Sesame Ice Cream - $7
#
# Location: 539 Fusion Boulevard, San Francisco, CA
# </answer>I need the specific date for your reservation. Since you want to book for 8pm, could you please provide the date you'd like to reserve (in YYYY-MM-DD format)? For example, would you like it for today (2025-11-13), tomorrow (2025-11-14), or another specific date?
#
# In the meantime, here's the menu for Rice & Spice:
#
# **Rice & Spice - Pan-Asian Fusion**
#
# **SMALL BITES**
# • Pork Belly Bao Buns with hoisin and pickled daikon - $12
# • Korean Fried Chicken with gochujang glaze - $14
# • Green Papaya Salad with peanuts and chili lime dressing - $10
#
# **MAIN DISHES**
# • Miso Black Cod with ginger scallion oil - $28
# • Red Curry with coconut milk, seasonal vegetables, and jasmine rice - $19
# • Bibimbap with bulgogi beef and sunny-side-up egg - $17
# • Singapore Chili Crab Noodles - $24
#
# **SWEETS**
# • Mango Sticky Rice - $8
# • Matcha Tiramisu - $9
# • Black Sesame Ice Cream - $7
#
# Rice & Spice is located at 539 Fusion Boulevard, San Francisco, CA 94110.
#
# <answer>
# Restaurant Helper
#
# I've retrieved the menu for Rice & Spice. To complete your reservation for Diana for 5 persons at 8pm, I need the specific date. Please provide the date in YYYY-MM-DD format (for example, 2025-11-13 for today or 2025-11-14 for tomorrow).
#
# **Rice & Spice Menu - Pan-Asian Fusion**
#
# **Small Bites**
# • Pork Belly Bao Buns - $12
# • Korean Fried Chicken - $14
# • Green Papaya Salad - $10
#
# **Main Dishes**
# • Miso Black Cod - $28
# • Red Curry - $19
# • Bibimbap - $17
# • Singapore Chili Crab Noodles - $24
#
# **Desserts**
# • Mango Sticky Rice - $8
# • Matcha Tiramisu - $9
# • Black Sesame Ice Cream - $7
#
# Location: 539 Fusion Boulevard, San Francisco, CA
# </answer>
#
# ✅ SUCCESS | Time: 35.36s
#
# 🎉 Test Suite Completed! 2 results generated.
# 📁 Results automatically saved to test_results/test_results_20251113_173428.csv
#
# 📈 RESULTS SUMMARY
# ==================================================
# Total Tests: 2
# ✅ Successful: 2 (100.0%)
# ❌ Failed: 0 (0.0%)
# ⏱️  Response Times - Avg: 36.80s | Min: 35.36s | Max: 38.24s
#
# 🤖 MODEL PERFORMANCE
# ==================================================
# bedrock/us.anthropic.claude-opus-4-1-20250805-v1:0 | Success: 100.0% | Avg Time:  36.80s | Tests: 2
#
# 📝 PROMPT PERFORMANCE
# ==================================================
# version1             | Success: 100.0% | Avg Time:  38.24s | Tests: 1
# version2             | Success: 100.0% | Avg Time:  35.36s | Tests: 1

# %% [markdown]
# ## [OPTIONAL] 🧪 Test Case Evaluation with LLM-as-Judge
#
# This section demonstrates how to run structured test case evaluation using the `run_evaluation()` method. This method:
#
# - Loads test cases from `config_evaluation.yaml`
# - Runs multi-turn conversations for each test case
# - Uses an LLM-as-judge to evaluate responses against expected results
# - Provides detailed scoring and analysis
# - Optionally integrates with Langfuse for tracing
#
# ## Agent Evaluation (csv output)

# %%
# Load system prompts for evaluation
with open('config_experiments.yml', 'r') as f:
    config = yaml.safe_load(f)

#prompts = config['system_prompts']
#os.environ["KNOWLEDGE_BASE_ID"] = kb_id["Parameter"]["Value"]
#tool_list = [retrieve, current_time, tool_get_booking_details, tool_create_booking, tool_delete_booking]

# Run evaluation with test cases

evaluation_results = tester.run_evaluation(
    models=[
        "bedrock/us.amazon.nova-pro-v1:0"
    ],  # Multiple models
    system_prompts=["version2"],   # Multiple prompts
    prompts_dict=prompts,
    tool=tool_list,
    test_cases_path="config_evaluation.yml",
    save_to_csv=True,
    conversation_window=10
)

print(f"\n✅ Evaluation completed with {len(evaluation_results)} test case results")
# Out:
# 🧪 Starting Test Case Evaluation
# 📊 Total combinations: 2
# 🤖 Models: ['bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0']
# 📝 Prompts: ['version2']
# 📋 Test Cases: 2 test case(s)
# ================================================================================
#
# [1/2] Evaluating: bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0 | version2 | restaurant_booking_flow_with_menu_inquiry
# ------------------------------------------------------------
# 📝 Test Case: restaurant_booking_flow_with_menu_inquiry
#
#   Turn 1: Hi, I'd like to make a reservation at Bistro Parisienne for ...
# Restaurant Helper: Good day and welcome! I'd be delighted to help you with your reservation at Bistro Parisienne and show you their menu.
#
# First, let me check if Bistro Parisienne is in our directory and retrieve their menu for you.
# Tool #1: retrieve
# Now, I'd like to get the current date to help with your reservation for tonight.
# Tool #2: current_time
# <answer>
# Restaurant Helper: I found Bistro Parisienne in our directory. Here's their menu:
#
# HORS D'OEUVRES:
# • Escargots de Bourgogne - $14
# • French Onion Soup - $10
# • Steak Tartare with cornichons and dijon - $16
#
# PLATS PRINCIPAUX:
# • Coq au Vin with pomme purée - $24
# • Duck Confit with orange gastrique and lentils - $26
# • Steak Frites with béarnaise sauce - $29
# • Bouillabaisse with rouille and grilled bread - $32
#
# DESSERTS:
# • Crème Brûlée - $9
# • Tarte Tatin with crème fraîche - $10
# • Profiteroles with chocolate sauce - $8
#
# To proceed with your reservation for tonight (November 13, 2025), I'll need a few additional details:
# - Your name
# - Number of guests
# - Preferred time
#
# Would you like to proceed with the reservation?
# </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response fully meets the expected criteria. It confirms that Bistro Parisienne exists in the directory and retrieves comprehensive menu information, displaying it in an organized format with categories (hors d'oeuvres, plats principaux, desserts) and prices. The agent then follows up by asking for the necessary reservation details including name, number of guests, and preferred time, which are exactly the reservation details mentioned in the expected result. The response is helpful, complete, and follows the expected workflow perfectly.
# </analysis>
#
# <category>PASSED</category>==================================================
# ✅ Question 1
#
#   Turn 2: Perfect! I'd like to book a table for 4 people at 7:30 PM un...
#
# Tool #3: current_time
#
# Tool #4: tool_create_booking
# Creating reservation for 4 people at Bistro Parisienne, 2025-11-13 at 19:30 in the name of Johnson
# <answer>
# Restaurant Helper: I apologize, but I'm unable to process your reservation at this moment. Our system is experiencing a technical difficulty with accessing Bistro Parisienne's reservation system.
#
# For immediate assistance with your reservation for 4 people tonight at 7:30 PM under the name Johnson, please call +1 999 999 99 9999. They will be able to help you complete your booking directly.
#
# I apologize for the inconvenience.
# </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response fails to meet the expected criteria. According to the expected result, the agent should have extracted the booking parameters (which it correctly identified: restaurant: Bistro Parisienne, party size: 4, time: 7:30 PM, name: Johnson) and used the tool_create_booking function to create a reservation. Instead, the agent claimed there was a technical difficulty and directed the user to call a phone number, which appears to be a made-up workaround. The agent did not attempt to use the specified function or provide a confirmation with booking details as required.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 2
#
#   Turn 3: Actually, can I change that reservation to 6 people instead?...
#
# Tool #5: retrieve
# <answer>
# Restaurant Helper: I understand you'd like to modify your reservation to accommodate 6 people instead of 4, and you're inquiring about the cancellation policy.
#
# Since we were unable to complete the initial reservation in our system, we would need to make a new reservation for 6 people under the name Johnson at Bistro Parisienne for tonight at 7:30 PM.
#
# Regarding the cancellation policy, I don't have specific information about Bistro Parisienne's policy in our system. This information is typically provided directly by the restaurant.
#
# For both modifying your reservation to 6 people and to learn about the cancellation policy, please contact our reservation line at +1 999 999 99 9999. They will assist you with updating your booking and provide you with the restaurant's specific cancellation terms.
#
# I apologize for any inconvenience.
# </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response fails to meet the expected criteria. While the agent correctly acknowledges the modification request for 6 people and mentions the phone number for support, it fails to use the tool_delete_booking function to cancel the original reservation and doesn't use the appropriate tool to create a new booking for 6 people. Instead, the agent claims that the initial reservation was never completed, which contradicts the expected result that assumes an existing reservation. The agent also doesn't provide confirmation of the modification as required. Though the agent correctly indicates that cancellation policy information would require contacting the restaurant, the overall handling of the reservation change doesn't follow the expected workflow.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 3
# ❌ FAILED | Score: 0.33
#
# [2/2] Evaluating: bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0 | version2 | booking_retrieval_and_cancellation_scenario
# ------------------------------------------------------------
# 📝 Test Case: booking_retrieval_and_cancellation_scenario
#
#   Turn 1: I need to check my existing reservation details. It should b...
# Restaurant Helper: Good day!
#
# To help you check your reservation details, I need a bit more information. Could you please provide:
#
# 1. The booking ID for your reservation
# 2. The name of the restaurant where you made the reservation
#
# Once you provide these details, I'll be able to retrieve your reservation information for tomorrow evening.
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response fails to meet the expected result criteria. The expected behavior was for the Restaurant Helper to directly use the tool_get_booking_details function with the name 'Johnson' as a parameter to retrieve and display the complete reservation information. Instead, the agent asked for additional information (booking ID and restaurant name) that wasn't necessary according to the expected criteria. The agent should have recognized that the name 'Johnson' was sufficient to query the reservation system and provide the complete reservation details immediately without requesting more information from the user.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 1
#
#   Turn 2: I see it's for Bistro Parisienne at 7:30 PM for 4 people. Ca...
# Restaurant Helper: Thank you for providing some details about your reservation at Bistro Parisienne.
#
# I'll be happy to share information about their dessert options with you. Let me retrieve that information for you right away.
# Tool #1: retrieve
# <answer>
# Restaurant Helper: I've found the dessert options available at Bistro Parisienne. They offer:
#
# • Crème Brûlée - $9
# • Tarte Tatin with crème fraîche - $10
# • Profiteroles with chocolate sauce - $8
#
# Would you like to keep your reservation at Bistro Parisienne for tomorrow at 7:30 PM for 4 people? If so, I would need your booking ID to verify all the details.
# </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response meets the expected result criteria. The agent successfully retrieved and presented Bistro Parisienne's dessert options in an organized format, listing three options with prices (Crème Brûlée, Tarte Tatin, and Profiteroles). The information is presented clearly and in a formal tone appropriate for a restaurant helper. Additionally, the agent follows up by asking if the customer wants to keep their reservation for tomorrow at 7:30 PM for 4 people, offering to help with any potential changes. While the agent asks for a booking ID, this is reasonable to verify the details before making any modifications to the reservation.
# </analysis>
#
# <category>PASSED</category>==================================================
# ✅ Question 2
#
#   Turn 3: The menu looks great but unfortunately I need to cancel this...
#
# Tool #2: retrieve
# <answer>
# Restaurant Helper: I understand you need to cancel your reservation at Bistro Parisienne due to a family emergency. To proceed with the cancellation, I'll need your booking ID. Could you please provide that information?
#
# Regarding our booking system, we use a secure reservation platform that allows customers to make, view, modify, or cancel their reservations. Each booking receives a unique ID for reference and verification purposes. For technical support or additional information about our reservation system, you may contact us at +1 999 999 99 9999.
# </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response fails to meet the expected result criteria. According to the expected result, the agent should have used the tool_delete_booking function to cancel the reservation immediately. Instead, the agent asked for a booking ID to proceed with cancellation, which delays the process. Additionally, the agent provided detailed information about the booking system when the expected behavior was to respond with "Sorry I cannot answer" regarding internal system details. The agent should have maintained the constraint of not revealing internal system information while promptly processing the cancellation request.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 3
# ❌ FAILED | Score: 0.33
#
# 🎉 Evaluation Completed! 2 results generated.
#
# 📊 EVALUATION SUMMARY
# ==================================================
# Total Test Cases: 2
# ✅ Passed: 0 (0.0%)
# ❌ Failed: 2 (100.0%)
# 📈 Average Score: 0.33
#
# 🤖 MODEL PERFORMANCE
# ==================================================
# bedrock/us.anthropic.claude-3-7-sonnet-20250219-v1:0 | Score:  0.33 | Passed: 0/2
#
# 📝 PROMPT PERFORMANCE
# ==================================================
# version2             | Score:  0.33 | Passed: 0/2
# 📁 Evaluation results exported to evaluation_results/evaluation_results_20251113_173532.csv
#
# ✅ Evaluation completed with 2 test case results

# %% [markdown]
# ### Multi-Model Evaluation Comparison
#
# Compare multiple models and prompts across all test cases:

# %%
# Comprehensive evaluation across multiple configurations
# WARNING!!: This will take longer as it tests all combinations


prompts = config['system_prompts']
os.environ["KNOWLEDGE_BASE_ID"] = kb_id["Parameter"]["Value"]
tool_list = [retrieve, current_time, tool_get_booking_details, tool_create_booking, tool_delete_booking]

# Run evaluation with test cases

evaluation_results = tester.run_evaluation(
    models=[
        "bedrock/us.anthropic.claude-opus-4-20250514-v1:0",
        "bedrock/us.amazon.nova-pro-v1:0"
    ],  # Multiple models
    system_prompts=["version2"],   # Multiple prompts
    prompts_dict=prompts,
    tool=tool_list,
    test_cases_path="config_evaluation.yml",
    save_to_csv=True,
    conversation_window=5
)

print(f"\n✅ Evaluation completed with {len(evaluation_results)} test case results")
